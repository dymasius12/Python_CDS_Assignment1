# %% [markdown]
# # Assignment 1A-II

# %% [markdown]
# ### Checking the installed library

# %%
# !pip list
# Out:
# Package              Version
# -------------------- -----------
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.8
# attrs                22.1.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               5.0.1
# certifi              2022.9.14
# cffi                 1.15.1
# colorama             0.4.5
# contourpy            1.0.5
# cycler               0.11.0
# debugpy              1.6.3
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# executing            1.0.0
# fastjsonschema       2.16.2
# fonttools            4.37.3
# importlib-metadata   4.12.0
# importlib-resources  5.9.0
# ipykernel            6.15.3
# ipython              8.5.0
# ipython-genutils     0.2.0
# ipywidgets           8.0.2
# jedi                 0.18.1
# Jinja2               3.1.2
# jsonschema           4.16.0
# jupyter              1.0.0
# jupyter_client       7.3.5
# jupyter-console      6.4.4
# ...

# %% [markdown]
# # Question 1:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
floor_fee = {'Basement':50, 'First Floor':40, 'Second Floor':30, 'Third Floor':20}

# %%
floor_fee
# Out:
# {'Basement': 50, 'First Floor': 40, 'Second Floor': 30, 'Third Floor': 20}

# %% [markdown]
# # Question 2:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Basement_details = ['R',2,'v',3,'v',2,'v',4,'R',6,'v',1,'R',2,'v',1,'v',2,'R',4]
Firstfloor_details = ['v',3,'v',3,'v',4,'R', 4,'R',1,'R',2,'v',1]
Secondfloor_details = ['v',12,'R', 6,'R',10,'R',12,'v',12]
parking_details = {'Basement': Basement_details, 'First Floor': Firstfloor_details, 'Second Floor':Secondfloor_details}

# %%
parking_details
# Out:
# {'Basement': ['R',
#   2,
#   'v',
#   3,
#   'v',
#   2,
#   'v',
#   4,
#   'R',
#   6,
#   'v',
#   1,
#   'R',
#   2,
#   'v',
#   1,
#   'v',
#   2,
#   'R',
#   4],
#  'First Floor': ['v', 3, 'v', 3, 'v', 4, 'R', 4, 'R', 1, 'R', 2, 'v', 1],
#  'Second Floor': ['v', 12, 'R', 6, 'R', 10, 'R', 12, 'v', 12]}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Make the legend first saving the amount need to pay
legend = {'R':0.25, 'v':1}
print(legend)
print(parking_details)
print(floor_fee)

Total = 0
for location in parking_details:
    percentage_pay = 0
    for record in parking_details[p]:
        hour = lambda location : floor_fee['Basement'] if location == 'Basement' else ( floor_fee['First Floor'] if location == 'First Floor' else floor_fee['Second Floor'])
        percentage = lambda record : legend['R'] if record == 'R' else (legend['v'] if record == 'v' else 0)
        
        price_hour = hour(location)
    
        if isinstance(record, str):
            
            percentage_pay = percentage(record)
            print('')
            print(f"record:{record}")
            print(f"percentage pay:{percentage_pay}")
            print(f"price_hour:{price_hour}")
            print(f"Total:{Total}")
        else:
            print('')
            Total = Total + (percentage_pay * record * price_hour)
            print(f"record:{record}")
            print(f"percentage pay:{percentage_pay}")
            print(f"price_hour:{price_hour}")
            
            
            
            print(f"Total:{Total}")
            
            
print(Total)
# Out:
# {'R': 0.25, 'v': 1}
# {'Basement': ['R', 2, 'v', 3, 'v', 2, 'v', 4, 'R', 6, 'v', 1, 'R', 2, 'v', 1, 'v', 2, 'R', 4], 'First Floor': ['v', 3, 'v', 3, 'v', 4, 'R', 4, 'R', 1, 'R', 2, 'v', 1], 'Second Floor': ['v', 12, 'R', 6, 'R', 10, 'R', 12, 'v', 12]}
# {'Basement': 50, 'First Floor': 40, 'Second Floor': 30, 'Third Floor': 20}
#
# record:v
# percentage pay:1
# price_hour:50
# Total:0
#
# record:12
# percentage pay:1
# price_hour:50
# Total:600
#
# record:R
# percentage pay:0.25
# price_hour:50
# Total:600
#
# record:6
# percentage pay:0.25
# price_hour:50
# Total:675.0
#
# record:R
# percentage pay:0.25
# price_hour:50
# Total:675.0
#
# record:10
# percentage pay:0.25
# price_hour:50
# Total:800.0
#
# record:R
# percentage pay:0.25
# price_hour:50
# Total:800.0
#
# record:12
# percentage pay:0.25
# price_hour:50
# Total:950.0
#
# record:v
# percentage pay:1
# price_hour:50
# Total:950.0
#
# record:12
# percentage pay:1
# price_hour:50
# Total:1550.0
#
# record:v
# percentage pay:1
# ...
